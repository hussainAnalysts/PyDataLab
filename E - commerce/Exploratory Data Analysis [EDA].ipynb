# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\user\Desktop\#\DA\practice\python\E - commerce\cleaned_data sets\merged_data.csv")

# %% [markdown]
# # EXPLORATORY DATA ANALYSIS [EDA]

# %%
# Initial Data Inspection
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 118434 entries, 0 to 118433
# Data columns (total 28 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       118434 non-null  object
#  1   customer_id                    118434 non-null  object
#  2   order_status                   118434 non-null  object
#  3   order_purchase_timestamp       118434 non-null  object
#  4   order_approved_at              118434 non-null  object
#  5   order_delivered_carrier_date   118434 non-null  object
#  6   order_delivered_customer_date  118434 non-null  object
#  7   order_estimated_delivery_date  118434 non-null  object
#  8   order_item_id                  118434 non-null  int64
#  9   product_id                     118434 non-null  int64
#  10  seller_id                      118434 non-null  int64
#  11  shipping_limit_date            118434 non-null  object
# ...

# %%
df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 3  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 4  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
#
#   order_status order_purchase_timestamp order_approved_at  \
# 0    delivered          10/2/2017 10:56   10/2/2017 11:07
# 1    delivered          10/2/2017 10:56   10/2/2017 11:07
# 2    delivered          10/2/2017 10:56   10/2/2017 11:07
# 3    delivered          7/24/2018 20:41    7/26/2018 3:24
# 4    delivered            8/8/2018 8:38     8/8/2018 8:55
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0              10/4/2017 19:55              10/10/2017 21:25
# 1              10/4/2017 19:55              10/10/2017 21:25
# ...

# %%
df.tail()
# Out:
#                                 order_id                       customer_id  \
# 118429  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 118430  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 118431  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 118432  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 118433  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#        order_status order_purchase_timestamp order_approved_at  \
# 118429    delivered           2/6/2018 12:58    2/6/2018 13:10
# 118430    delivered          8/27/2017 14:46   8/27/2017 15:04
# 118431    delivered           1/8/2018 21:28    1/8/2018 21:36
# 118432    delivered           1/8/2018 21:28    1/8/2018 21:36
# 118433    delivered           3/8/2018 20:57    3/9/2018 11:20
#
#        order_delivered_carrier_date order_delivered_customer_date  \
# ...

# %%
df.describe()
# Out:
#        order_item_id  product_id  seller_id          price  freight_value  \
# count  118434.000000    118434.0   118434.0  118434.000000  118434.000000
# mean        1.180531        -1.0       -1.0     120.501016      20.019232
# std         0.718999         0.0        0.0     183.869718      15.808778
# min        -1.000000        -1.0       -1.0       0.850000       0.000000
# 25%         1.000000        -1.0       -1.0      39.900000      13.080000
# 50%         1.000000        -1.0       -1.0      74.900000      16.290000
# 75%         1.000000        -1.0       -1.0     133.000000      21.150000
# max        21.000000        -1.0       -1.0    6735.000000     409.680000
#
#        product_weight_g  customer_zip_code_prefix  payment_sequential  \
# count     118434.000000             118434.000000       118434.000000
# mean        2099.225096              35034.264392            1.094179
# std         3779.295179              29819.290218            0.728301
# ...

# %%
df.describe(include=['object'])
# Out:
#                                 order_id                       customer_id  \
# count                             118434                            118434
# unique                             99441                             99441
# top     895ab968e7bb0d5659d16cd74cd1650c  270c23a11d024a44c896d1894b261a83
# freq                                  63                                63
#
#        order_status order_purchase_timestamp order_approved_at  \
# count        118434                   118434            118434
# unique            8                    88789             50610
# top       delivered           8/8/2017 20:26   1/10/2018 10:32
# freq         115038                       63               121
#
#        order_delivered_carrier_date order_delivered_customer_date  \
# count                        118434                        118434
# unique                        63124                         78196
# top                 8/10/2017 11:58               8/14/2017 12:46
# ...

# %%
# Missing Values Analysis
print(df.isnull().sum())
# Out:
# order_id                             0
# customer_id                          0
# order_status                         0
# order_approved_at                    0
# order_delivered_carrier_date         0
# order_delivered_customer_date        0
# order_estimated_delivery_date        0
# order_item_id                        0
# product_id                           0
# seller_id                            0
# shipping_limit_date                  0
# price                                0
# freight_value                        0
# product_category_name                0
# product_category_name_eng            0
# product_weight_g                     0
# customer_unique_id                   0
# customer_zip_code_prefix             0
# customer_city                        0
# customer_state                       0
# payment_sequential                   0
# payment_type                         0
# payment_installments                 0
# payment_value                        0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 118434 entries, 0 to 118433
# Data columns (total 28 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       118434 non-null  object
#  1   customer_id                    118434 non-null  object
#  2   order_status                   118434 non-null  object
#  3   order_purchase_timestamp       118434 non-null  object
#  4   order_approved_at              118434 non-null  object
#  5   order_delivered_carrier_date   118434 non-null  object
#  6   order_delivered_customer_date  118434 non-null  object
#  7   order_estimated_delivery_date  118434 non-null  object
#  8   order_item_id                  118434 non-null  int64
#  9   product_id                     118434 non-null  int64
#  10  seller_id                      118434 non-null  int64
#  11  shipping_limit_date            118434 non-null  object
# ...

# %%
df.columns
# Out:
# Index(['order_id', 'customer_id', 'order_status', 'order_purchase_timestamp',
#        'order_approved_at', 'order_delivered_carrier_date',
#        'order_delivered_customer_date', 'order_estimated_delivery_date',
#        'order_item_id', 'product_id', 'seller_id', 'shipping_limit_date',
#        'price', 'freight_value', 'product_category_name',
#        'product_category_name_eng', 'product_weight_g', 'customer_unique_id',
#        'customer_zip_code_prefix', 'customer_city', 'customer_state',
#        'payment_sequential', 'payment_type', 'payment_installments',
#        'payment_value', 'seller_zip_code_prefix', 'seller_city',
#        'seller_state'],
#       dtype='object')

# %% [markdown]
# ### Changing the columns to appropite data types

# %%
df['order_id'] = df['order_id'].astype(str)  # Identifier columns
df['customer_id'] = df['customer_id'].astype(str)
df['order_status'] = df['order_status'].astype(str)  # Categorical/text data
df['order_purchase_timestamp'] = pd.to_datetime(df['order_purchase_timestamp'], errors='coerce')  # DateTime
df['order_approved_at'] = pd.to_datetime(df['order_approved_at'], errors='coerce')  # DateTime
df['order_delivered_carrier_date'] = pd.to_datetime(df['order_delivered_carrier_date'], errors='coerce')  # DateTime
df['order_delivered_customer_date'] = pd.to_datetime(df['order_delivered_customer_date'], errors='coerce')  # DateTime
df['order_estimated_delivery_date'] = pd.to_datetime(df['order_estimated_delivery_date'], errors='coerce')  # DateTime
df['order_item_id'] = pd.to_numeric(df['order_item_id'], errors='coerce')  # Integer
df['product_id'] = df['product_id'].astype(str)  # Identifier
df['seller_id'] = df['seller_id'].astype(str)  # Identifier
df['shipping_limit_date'] = pd.to_datetime(df['shipping_limit_date'], errors='coerce')  # DateTime
df['price'] = pd.to_numeric(df['price'], errors='coerce')  # Numeric
df['freight_value'] = pd.to_numeric(df['freight_value'], errors='coerce')  # Numeric
df['product_category_name'] = df['product_category_name'].astype(str)  # Categorical/text data
df['product_weight_g'] = pd.to_numeric(df['product_weight_g'], errors='coerce')  # Numeric
df['customer_unique_id'] = df['customer_unique_id'].astype(str)  # Identifier
df['customer_zip_code_prefix'] = df['customer_zip_code_prefix'].astype(str)  # Categorical/text data
df['customer_city'] = df['customer_city'].astype(str)  # Categorical/text data
df['customer_state'] = df['customer_state'].astype(str)  # Categorical/text data
df['payment_sequential'] = pd.to_numeric(df['payment_sequential'], errors='coerce')  # Numeric
df['payment_type'] = df['payment_type'].astype(str)  # Categorical/text data
df['payment_installments'] = pd.to_numeric(df['payment_installments'], errors='coerce')  # Numeric
df['payment_value'] = pd.to_numeric(df['payment_value'], errors='coerce')  # Numeric
df['seller_zip_code_prefix'] = df['seller_zip_code_prefix'].astype(str)  # Categorical/text data
df['seller_city'] = df['seller_city'].astype(str)  # Categorical/text data
df['seller_state'] = df['seller_state'].astype(str)  # Categorical/text data
df['product_category_name_eng'] = df['product_category_name_eng'].astype(str)  # Categorical/text data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 118434 entries, 0 to 118433
# Data columns (total 28 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       118434 non-null  object
#  1   customer_id                    118434 non-null  object
#  2   order_status                   118434 non-null  object
#  3   order_purchase_timestamp       118434 non-null  datetime64[ns]
#  4   order_approved_at              118434 non-null  datetime64[ns]
#  5   order_delivered_carrier_date   118434 non-null  datetime64[ns]
#  6   order_delivered_customer_date  118434 non-null  datetime64[ns]
#  7   order_estimated_delivery_date  118434 non-null  datetime64[ns]
#  8   order_item_id                  118434 non-null  int64
#  9   product_id                     118434 non-null  object
#  10  seller_id                      118434 non-null  object
# ...

# %%
df.isnull().sum()
# Out:
# order_id                         0
# customer_id                      0
# order_status                     0
# order_purchase_timestamp         0
# order_approved_at                0
# order_delivered_carrier_date     0
# order_delivered_customer_date    0
# order_estimated_delivery_date    0
# order_item_id                    0
# product_id                       0
# seller_id                        0
# shipping_limit_date              0
# price                            0
# freight_value                    0
# product_category_name            0
# product_category_name_eng        0
# product_weight_g                 0
# customer_unique_id               0
# customer_zip_code_prefix         0
# customer_city                    0
# customer_state                   0
# payment_sequential               0
# payment_type                     0
# payment_installments             0
# payment_value                    0
# seller_zip_code_prefix           0
# seller_city                      0
# ...

# %%
df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 3  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 4  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:00 2017-10-02 11:07:00
# 1    delivered      2017-10-02 10:56:00 2017-10-02 11:07:00
# 2    delivered      2017-10-02 10:56:00 2017-10-02 11:07:00
# 3    delivered      2018-07-24 20:41:00 2018-07-26 03:24:00
# 4    delivered      2018-08-08 08:38:00 2018-08-08 08:55:00
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:00
# ...

# %%
# Set the display option to show all columns
pd.set_option('display.max_columns', None)
# Set the display option to show all rows
pd.set_option('display.max_rows', None)

# %%
df.columns
# Out:
# Index(['order_id', 'customer_id', 'order_status', 'order_purchase_timestamp',
#        'order_approved_at', 'order_delivered_carrier_date',
#        'order_delivered_customer_date', 'order_estimated_delivery_date',
#        'order_item_id', 'product_id', 'seller_id', 'shipping_limit_date',
#        'price', 'freight_value', 'product_category_name',
#        'product_category_name_eng', 'product_weight_g', 'customer_unique_id',
#        'customer_zip_code_prefix', 'customer_city', 'customer_state',
#        'payment_sequential', 'payment_type', 'payment_installments',
#        'payment_value', 'seller_zip_code_prefix', 'seller_city',
#        'seller_state'],
#       dtype='object')

# %%
df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 3  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 4  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:00 2017-10-02 11:07:00
# 1    delivered      2017-10-02 10:56:00 2017-10-02 11:07:00
# 2    delivered      2017-10-02 10:56:00 2017-10-02 11:07:00
# 3    delivered      2018-07-24 20:41:00 2018-07-26 03:24:00
# 4    delivered      2018-08-08 08:38:00 2018-08-08 08:55:00
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:00
# ...

# %%
df.shape
# Out:
# (118434, 28)

# %% [markdown]
# ##  Data Filtering

# %%
# Filtering rows where order_status is 'delivered'
df_delivered = df[df['order_status'] == 'delivered']
df_delivered.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 3  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 4  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:00 2017-10-02 11:07:00
# 1    delivered      2017-10-02 10:56:00 2017-10-02 11:07:00
# 2    delivered      2017-10-02 10:56:00 2017-10-02 11:07:00
# 3    delivered      2018-07-24 20:41:00 2018-07-26 03:24:00
# 4    delivered      2018-08-08 08:38:00 2018-08-08 08:55:00
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:00
# ...

# %%
# Filtering multiple conditions
df_filtered_m = df[(df['price'] > 100) & (df['order_status'] == 'shipped')]
df_filtered_m.head()
# Out:
#                              order_id                       customer_id  \
# 278  4d630f57194f5aba1a3d12ce23e71cd9  6d491c9fe2f04f6e2af6ec033cd8907c
# 355  3b4ad687e7e5190db827e1ae5a8989dd  1a87b8517b7d31373b50396eb15cb445
# 361  b68d69564a79dea4776afa33d1d2fcab  de1e5517fb50896bbdcff5814fb31802
# 445  5869074071e0f56e9085dc3742c97b2a  7203eb38fea2b4a15dd6c39575314aa4
# 696  f633c884a99eb63866600655356d973e  b6e18008af6aeb4a5ce5574c15ca2b48
#
#     order_status order_purchase_timestamp   order_approved_at  \
# 278      shipped      2017-11-17 19:53:00 2017-11-18 19:50:00
# 355      shipped      2018-06-28 12:52:00 2018-06-28 13:11:00
# 361      shipped      2018-02-28 08:57:00 2018-02-28 10:40:00
# 445      shipped      2018-06-08 20:06:00 2018-06-12 04:35:00
# 696      shipped      2018-04-04 00:33:00 2018-04-04 00:48:00
#
#     order_delivered_carrier_date order_delivered_customer_date  \
# 278          2017-11-22 17:28:00           2017-11-17 19:53:00
# ...

# %%
# Filtering rows where 'customer_city' contains the substring 'Rio'
df_rio_customers = df[df['customer_city'].str.contains('Rio', case=False)]
df_rio_customers.head()
# Out:
#                             order_id                       customer_id  \
# 13  e6ce16cb79ec1d90b1da9085a6118aeb  494dded5b201313c64ed7f100595b95c
# 14  e6ce16cb79ec1d90b1da9085a6118aeb  494dded5b201313c64ed7f100595b95c
# 20  403b97836b0c04a622354cf531062e5f  738b086814c6fcc74b8cc583f8516ee3
# 31  fbf9ac61453ac646ce8ad9783d7d0af6  3a874b4d4c4b6543206ff5d89287f0c3
# 52  6ebaec694d7025e2ad4a05dba887c032  4f28355e5c17a4a42d3ce2439a1d4501
#
#    order_status order_purchase_timestamp   order_approved_at  \
# 13    delivered      2017-05-16 19:41:00 2017-05-16 19:50:00
# 14    delivered      2017-05-16 19:41:00 2017-05-16 19:50:00
# 20    delivered      2018-01-02 19:00:00 2018-01-02 19:09:00
# 31    delivered      2018-02-20 23:46:00 2018-02-22 02:30:00
# 52    delivered      2017-05-18 13:55:00 2017-05-18 14:05:00
#
#    order_delivered_carrier_date order_delivered_customer_date  \
# 13          2017-05-18 11:40:00           2017-05-29 11:18:00
# ...

# %%
# Filtering rows where 'order_status' is either 'shipped' or 'delivered' and 'payment_type' is 'credit_card'
df_filtered_p = df[(df['order_status'].isin(['shipped', 'delivered'])) & (df['payment_type'] == 'credit_card')]
df_filtered_p.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 4  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 5  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 6  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# 7  a4591c265e18cb1dcee52889e2d8acc3  503740e9ca751ccdda7ba28e9ab8f608
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:00 2017-10-02 11:07:00
# 4    delivered      2018-08-08 08:38:00 2018-08-08 08:55:00
# 5    delivered      2017-11-18 19:28:00 2017-11-18 19:45:00
# 6    delivered      2018-02-13 21:18:00 2018-02-13 22:20:00
# 7    delivered      2017-07-09 21:57:00 2017-07-09 22:10:00
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:00
# ...

# %%
# Filtering rows where the order was delivered later than the estimated delivery date
df_late_delivery = df[df['order_delivered_customer_date'] > df['order_estimated_delivery_date']]
df_late_delivery.head()
# Out:
#                             order_id                       customer_id  \
# 26  203096f03d82e0dffbc41ebc2e2bcfb7  d2b091571da224a1b36412c18bc3bbfe
# 31  fbf9ac61453ac646ce8ad9783d7d0af6  3a874b4d4c4b6543206ff5d89287f0c3
# 42  8563039e855156e48fccee4d611a3196  5f16605299d698660e0606f7eae2d2f9
# 48  6ea2f835b4556291ffdc53fa0b3b95e8  c7340080e394356141681bd4c9b8fe31
# 65  66e4624ae69e7dc89bd50222b59f581f  684fa6da5134b9e4dab731e00011712d
#
#    order_status order_purchase_timestamp   order_approved_at  \
# 26    delivered      2017-09-18 14:31:00 2017-09-19 04:04:00
# 31    delivered      2018-02-20 23:46:00 2018-02-22 02:30:00
# 42    delivered      2018-02-17 15:59:00 2018-02-17 16:15:00
# 48    delivered      2017-11-24 21:27:00 2017-11-25 00:21:00
# 65    delivered      2018-03-09 14:50:00 2018-03-09 15:40:00
#
#    order_delivered_carrier_date order_delivered_customer_date  \
# 26          2017-10-06 17:50:00           2017-10-09 22:23:00
# ...

# %%
# Filtering rows where 'product_category_name' starts with 'e'
df_filtered_pro = df[df['product_category_name_eng'].str.contains('^e', regex=True, na=False)]
df_filtered_pro["product_category_name_eng"].head(12)
# Out:
# 28     electronics
# 43     electronics
# 209    electronics
# 453    electronics
# 454    electronics
# 493    electronics
# 556    electronics
# 581    electronics
# 604    electronics
# 616    electronics
# 665    electronics
# 771    electronics
# Name: product_category_name_eng, dtype: object

# %%
# Filtering rows where 'order_delivered_customer_date' is null
df_null_delivery = df[df['order_delivered_customer_date'].isnull()]
df_null_delivery
# Out:
# Empty DataFrame
# Columns: [order_id, customer_id, order_status, order_purchase_timestamp, order_approved_at, order_delivered_carrier_date, order_delivered_customer_date, order_estimated_delivery_date, order_item_id, product_id, seller_id, shipping_limit_date, price, freight_value, product_category_name, product_category_name_eng, product_weight_g, customer_unique_id, customer_zip_code_prefix, customer_city, customer_state, payment_sequential, payment_type, payment_installments, payment_value, seller_zip_code_prefix, seller_city, seller_state]
# Index: []

# %%
# Filtering rows using query function with complex conditions
df_filtered_q = df.query("price > 1000 and order_status == 'shipped'")
df_filtered_q[["price", "order_status"]]
# Out:
#          price order_status
# 4518   2150.00      shipped
# 9713   2110.00      shipped
# 35661  1399.00      shipped
# 50569  1599.99      shipped
# 67650  1300.00      shipped
# 71608  1697.00      shipped
# 95079  1989.00      shipped

# %%
# Filtering rows where length of 'customer_city' is greater than 10
df_filtered_cus = df[df['customer_city'].str.len() > 10]
df_filtered_cus["customer_city"].head()
# Out:
# 5     sao goncalo do amarante
# 6                 santo andre
# 7                congonhinhas
# 10               faxinalzinho
# 13             rio de janeiro
# Name: customer_city, dtype: object

# %%
# Filtering rows where both 'price' and 'freight_value' are greater than 100
df_filtered_freight = df[(df[['price', 'freight_value']] > 400).all(axis=1)]
df_filtered_freight[["price", "freight_value"]]
# Out:
#        price  freight_value
# 60066  979.0         409.68

# %%
# Filtering rows where cumulative sum of 'price' exceeds 10,000
df['cumsum_price'] = df['price'].cumsum()
df_filtered_cum = df[df['cumsum_price'] > 10000]
df_filtered_cum[["price", "cumsum_price"]].head()
# Out:
#      price  cumsum_price
# 95   24.99      10018.36
# 96  219.00      10237.36
# 97  219.00      10456.36
# 98   93.00      10549.36
# 99   93.00      10642.36

# %%
df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 3  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 4  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:00 2017-10-02 11:07:00
# 1    delivered      2017-10-02 10:56:00 2017-10-02 11:07:00
# 2    delivered      2017-10-02 10:56:00 2017-10-02 11:07:00
# 3    delivered      2018-07-24 20:41:00 2018-07-26 03:24:00
# 4    delivered      2018-08-08 08:38:00 2018-08-08 08:55:00
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:00
# ...

# %%
# Filterind rows where sum of 'price' and 'freight_value' exceeds 300
df_filtered_f_p = df[df.apply(lambda row: row['price'] + row['freight_value'], axis=1) > 300]
df_filtered_f_p[["price","freight_value"]].head()
# Out:
#      price  freight_value
# 20  1299.0          77.45
# 37   279.0          34.19
# 45   445.0          63.17
# 48   339.0          17.12
# 61   369.0          17.33

# %%
df_filtered_time.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 df_filtered_time.head()
#
# NameError: name 'df_filtered_time' is not defined

# %%
# Filter ingrows where the delivery time is greater than 7 days
df['delivery_time'] = (df['order_delivered_customer_date'] - df['order_purchase_timestamp']).dt.days
df_filtered_time = df[df['delivery_time'] > 7]
df_filtered_time.head(6)
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 3  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 4  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 5  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:00 2017-10-02 11:07:00
# 1    delivered      2017-10-02 10:56:00 2017-10-02 11:07:00
# 2    delivered      2017-10-02 10:56:00 2017-10-02 11:07:00
# 3    delivered      2018-07-24 20:41:00 2018-07-26 03:24:00
# 4    delivered      2018-08-08 08:38:00 2018-08-08 08:55:00
# 5    delivered      2017-11-18 19:28:00 2017-11-18 19:45:00
#
# ...

# %%
# Ensure 'order_purchase_timestamp' is datetime
df['order_purchase_timestamp'] = pd.to_datetime(df['order_purchase_timestamp'])

# Filter orders within the specified date range
df_2021 = df[(df['order_purchase_timestamp'] >= '2021-01-01') & 
            (df['order_purchase_timestamp'] <= '2021-12-31')]
df_2021
# Out:
# Empty DataFrame
# Columns: [order_id, customer_id, order_status, order_purchase_timestamp, order_approved_at, order_delivered_carrier_date, order_delivered_customer_date, order_estimated_delivery_date, order_item_id, product_id, seller_id, shipping_limit_date, price, freight_value, product_category_name, product_category_name_eng, product_weight_g, customer_unique_id, customer_zip_code_prefix, customer_city, customer_state, payment_sequential, payment_type, payment_installments, payment_value, seller_zip_code_prefix, seller_city, seller_state, cumsum_price, delivery_time]
# Index: []

# %%
# date with hightest order
# 1. Extract the date from 'order_purchase_timestamp' and create a new column 'order_date'
df['order_date'] = df['order_purchase_timestamp'].dt.date

# 2. Group by 'order_date' and count the number of orders per date
order_counts = df.groupby('order_date').size()

# 3. Find the date with the maximum number of orders
max_order_date = order_counts.idxmax()
max_order_count = order_counts.max()

print(f"The date with the highest number of orders is {max_order_date} with {max_order_count} orders.")
# Out:
# The date with the highest number of orders is 2017-11-24 with 1420 orders.

# %%
# date with hightest order in list form 
# 1. Extract the date from 'order_purchase_timestamp' and create a new column 'order_date'
df['order_date'] = df['order_purchase_timestamp'].dt.date

# 2. Group by 'order_date' and counting the number of orders per date
order_counts = df.groupby('order_date').size()

# 3. Sorting the dates based on the number of orders in descending order
sorted_order_counts = order_counts.sort_values(ascending=False)

# 4. Converting the sorted result into a list of tuples (date, number of orders)
sorted_order_list = list(sorted_order_counts.items())

# to Display the sorted list
for date, count in sorted_order_list:
    print(f"Date: {date}, Number of Orders: {count}")
# Out:
# Date: 2017-11-24, Number of Orders: 1420
# Date: 2017-11-25, Number of Orders: 622
# Date: 2017-11-27, Number of Orders: 499
# Date: 2017-11-26, Number of Orders: 481
# Date: 2017-11-28, Number of Orders: 453
# Date: 2018-08-06, Number of Orders: 445
# Date: 2018-08-07, Number of Orders: 444
# Date: 2018-05-15, Number of Orders: 441
# Date: 2018-05-07, Number of Orders: 429
# Date: 2018-05-14, Number of Orders: 425
# Date: 2018-05-16, Number of Orders: 419
# Date: 2018-05-09, Number of Orders: 409
# Date: 2017-11-29, Number of Orders: 388
# Date: 2018-07-31, Number of Orders: 388
# Date: 2018-05-08, Number of Orders: 387
# Date: 2017-12-04, Number of Orders: 379
# Date: 2018-02-14, Number of Orders: 378
# Date: 2018-03-19, Number of Orders: 376
# Date: 2018-01-22, Number of Orders: 375
# Date: 2018-01-16, Number of Orders: 375
# Date: 2018-08-16, Number of Orders: 374
# Date: 2018-02-22, Number of Orders: 374
# Date: 2018-05-03, Number of Orders: 373
# ...

# %% [markdown]
# ## Data Aggregation and Grouping

# %%
# Grouping 'customer_state' and sum 'payment_value'
df_state_payment = df.groupby('customer_state')['payment_value'].sum().reset_index()
df_state_payment.head()
# Out:
#   customer_state  payment_value
# 0             AC       24984.86
# 1             AL      111993.78
# 2             AM       34873.79
# 3             AP       21642.70
# 4             BA      802416.72

# %%
# Grouping 'seller_state' and 'product_category_name_eng' and computing mean of 'freight_value'
df_seller_freight = df.groupby(['seller_state', 'product_category_name_eng'])['freight_value'].mean().reset_index()
df_seller_freight.head(22)
# Out:
#    seller_state   product_category_name_eng  freight_value
# 0            AC             books_technical      32.840000
# 1            AM                   telephony      27.266667
# 2            BA                        baby      47.908000
# 3            BA                   computers      46.447251
# 4            BA       computers_accessories      46.567347
# 5            BA                  cool_stuff      26.060000
# 6            BA                      drinks      15.470000
# 7            BA                 electronics       9.913333
# 8            BA    fashion_bags_accessories      31.757500
# 9            BA             fixed_telephony      49.296667
# 10           BA                  food_drink      21.849512
# 11           BA             furniture_decor      42.380000
# 12           BA                garden_tools      69.740000
# 13           BA               health_beauty      27.325000
# 14           BA                    pet_shop      24.730000
# ...

# %%
# Grouping 'customer_state' and calculate the 90th percentile of 'price'
import numpy as np
df_90th_percentile = df.groupby('customer_state')['price'].apply(lambda x: np.percentile(x, 90)).reset_index()
df_90th_percentile.head()
# Out:
#   customer_state   price
# 0             AC  394.60
# 1             AL  367.30
# 2             AM  253.50
# 3             AP  253.63
# 4             BA  259.90

# %%
# Grouping 'customer_city' and compute standard deviation of 'price'
df_std_price = df.groupby('customer_city')['price'].agg(np.std).reset_index()
df_std_price.head()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_7972\4028974231.py:2: FutureWarning: The provided callable <function std at 0x000002666601F1A0> is currently using SeriesGroupBy.std. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "std" instead.
#   df_std_price = df.groupby('customer_city')['price'].agg(np.std).reset_index()
#          customer_city       price
# 0  abadia dos dourados   79.550634
# 1            abadiania         NaN
# 2               abaete  115.348721
# 3           abaetetuba  406.659047
# 4              abaiara   53.103719

# %%
# Ranking all orders by 'price' in descending order
df['global_rank'] = df['price'].rank(method='min', ascending=False)
df['global_rank'].sort_values().head()
# Out:
# 26332    1.0
# 33775    2.0
# 4132     3.0
# 63493    4.0
# 48074    5.0
# Name: global_rank, dtype: float64

# %%
df.sort_values(by="global_rank", ascending=True).head()
# Out:
#                                order_id                       customer_id  \
# 26332  0812eb902a67711a1cb742b3cdaa65ae  c6e2731c5b391845f6800c97401a43a9
# 33775  fefacc66af859508bf1a7934eab1e97f  f48d464a0baaea338cb25f816991ab1f
# 4132   f5136e38d1a14a4dbd87dff67da82701  3fd6777bbce08a352fddd04e4a7cc8f6
# 63493  a96610ab360d42a2e5335a3998b4718a  df55c14d1476a9a3467f131269c2477f
# 48074  199af31afc78c699f0dbf71fb178d4d4  24bbf5fd2f2e1b359ee7de94defc4a15
#
#       order_status order_purchase_timestamp   order_approved_at  \
# 26332    delivered      2017-02-12 20:37:00 2017-02-12 20:45:00
# 33775    delivered      2018-07-25 18:10:00 2018-07-27 04:05:00
# 4132     delivered      2017-05-24 18:14:00 2017-05-26 02:45:00
# 63493    delivered      2017-04-01 15:58:00 2017-04-03 13:25:00
# 48074    delivered      2017-04-18 18:50:00 2017-04-19 15:50:00
#
#       order_delivered_carrier_date order_delivered_customer_date  \
# 26332          2017-02-16 09:23:00           2017-03-03 14:23:00
# ...

# %%
# top 10 orders by 'price' within each 'product_category_name_eng'
df_top10 = df.groupby('product_category_name_eng').apply(lambda x: x.nlargest(10, 'price')).reset_index(drop=True)
df_top10[["price", "product_category_name_eng"]].head(10)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_7972\1431138129.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_top10 = df.groupby('product_category_name_eng').apply(lambda x: x.nlargest(10, 'price')).reset_index(drop=True)
#     price   product_category_name_eng
# 0  2990.0  agro_industry_and_commerce
# 1  2399.0  agro_industry_and_commerce
# 2  2199.0  agro_industry_and_commerce
# 3  1899.0  agro_industry_and_commerce
# 4  1476.3  agro_industry_and_commerce
# 5  1390.0  agro_industry_and_commerce
# 6  1330.0  agro_industry_and_commerce
# 7  1234.0  agro_industry_and_commerce
# 8  1180.0  agro_industry_and_commerce
# 9  1180.0  agro_industry_and_commerce

# %%
# Grouped  customer_state and seller_state, then aggregate payment_value (sum) and freight_value (mean)
grouped_by_state = df.groupby(['customer_state', 'seller_state']).agg({
    'payment_value': 'sum',
    'freight_value': 'mean'
}).reset_index()
grouped_by_state.head(12)
# Out:
#    customer_state seller_state  payment_value  freight_value
# 0              AC           BA        1251.70      51.700000
# 1              AC           DF         225.42      26.420000
# 2              AC           GO         147.59      48.600000
# 3              AC           MA          94.74      27.750000
# 4              AC           MG        2578.91      48.968182
# 5              AC           MS         825.24      21.410000
# 6              AC           PR         218.95      39.050000
# 7              AC           RJ          50.14      33.240000
# 8              AC           RS         293.99      37.455000
# 9              AC           SC        1776.85      47.244000
# 10             AC           SP       17521.33      38.879710
# 11             AL           AM         984.26      35.260000

# %%
# Finding the most frequently occurring payment_type for each customer_state
most_frequent_payment_type = df.groupby('customer_state')['payment_type'].agg(lambda x: x.value_counts().idxmax())
most_frequent_payment_type
# Out:
# customer_state
# AC    credit_card
# AL    credit_card
# AM    credit_card
# AP    credit_card
# BA    credit_card
# CE    credit_card
# DF    credit_card
# ES    credit_card
# GO    credit_card
# MA    credit_card
# MG    credit_card
# MS    credit_card
# MT    credit_card
# PA    credit_card
# PB    credit_card
# PE    credit_card
# PI    credit_card
# PR    credit_card
# RJ    credit_card
# RN    credit_card
# RO    credit_card
# RR    credit_card
# RS    credit_card
# SC    credit_card
# SE    credit_card
# SP    credit_card
# TO    credit_card
# Name: payment_type, dtype: object

# %%
# Computing the cumulative sum of price within each seller_id
df['cumulative_price'] = df.groupby('seller_id')['price'].cumsum()
df[['seller_id','price','cumulative_price']].head()
# Out:
#   seller_id   price  cumulative_price
# 0        -1   29.99             29.99
# 1        -1   29.99             59.98
# 2        -1   29.99             89.97
# 3        -1  118.70            208.67
# 4        -1  159.90            368.57

# %%
# Calculating the percentage contribution of each seller_state to the total payment_value
total_payment_value = df['payment_value'].sum()
payment_by_seller_state = df.groupby('seller_state')['payment_value'].sum()
percentage_contribution = (payment_by_seller_state / total_payment_value) * 100
percentage_contribution.head(22)
# Out:
# seller_state
# AC    0.001465
# AM    0.006149
# BA    1.797169
# CE    0.126275
# DF    0.673072
# ES    0.385127
# GO    0.548008
# MA    0.253934
# MG    7.643759
# MS    0.052885
# MT    0.115475
# PA    0.006805
# PB    0.100680
# PE    0.610105
# PI    0.015556
# PR    9.019431
# RJ    5.364855
# RN    0.066235
# RO    0.027127
# RS    2.736725
# SC    4.331705
# SE    0.012047
# Name: payment_value, dtype: float64

# %%
# Grouping product_category_name_eng and calculating sum and mean of price and freight_value
aggregated_stats = df.groupby('product_category_name_eng').agg({
    'price': ['sum', 'mean'],
    'freight_value': ['sum', 'mean']
}).reset_index()
aggregated_stats.head()
# Out:
#     product_category_name_eng     price             freight_value
#                                     sum        mean           sum       mean
# 0  agro_industry_and_commerce  83841.95  332.706151       6966.82  27.646111
# 1            air_conditioning  55962.38  185.305894       6848.50  22.677152
# 2                         art  24721.97  112.885708       4191.02  19.137078
# 3       arts_and_craftmanship   1814.01   75.583750        370.13  15.422083
# 4                       audio  52450.37  138.027289       5979.79  15.736289

# %%
# Retrieving the first and last order_purchase_timestamp for each customer_id
first_last_order_dates = df.groupby('customer_id').agg({
    'order_purchase_timestamp': ['first', 'last']
}).reset_index()
first_last_order_dates.head()
# Out:
#                         customer_id order_purchase_timestamp  \
#                                                        first
# 0  00012a2ce6f8dcda20d059ce98491703      2017-11-14 16:08:00
# 1  000161a058600d5901f007fab4c27140      2017-07-16 09:40:00
# 2  0001fd6190edaaf884bcaf3d49edf079      2017-02-28 11:06:00
# 3  0002414f95344307404f0ace7a26f1d5      2017-08-16 13:09:00
# 4  000379cdec625522490c315e70c7a9fb      2018-04-02 13:42:00
#
#
#                  last
# 0 2017-11-14 16:08:00
# 1 2017-07-16 09:40:00
# 2 2017-02-28 11:06:00
# 3 2017-08-16 13:09:00
# 4 2018-04-02 13:42:00

# %%
# Counting unique product_id values for each seller_id
unique_products_per_seller = df.groupby('seller_id')['product_id'].nunique().reset_index(name='unique_products_sold')
unique_products_per_seller.head()
# Out:
#   seller_id  unique_products_sold
# 0        -1                     1

# %%
# Calculating the standard deviation of price and freight_value for each product_category_name_eng
std_deviation_stats = df.groupby('product_category_name_eng').agg({
    'price': 'std',
    'freight_value': 'std'
}).reset_index()
std_deviation_stats.head()
# Out:
#     product_category_name_eng       price  freight_value
# 0  agro_industry_and_commerce  393.780013      20.316324
# 1            air_conditioning  188.456727      14.059847
# 2                         art  435.611356      16.580166
# 3       arts_and_craftmanship   73.997815      12.267814
# 4                       audio  158.707023       6.608223

# %%
# Counting how many times the order_status was "delivered" for each seller_state
delivered_orders_count = df[df['order_status'] == 'delivered'].groupby('seller_state').size().reset_index(name='delivered_orders_count')
delivered_orders_count.sort_values(by="delivered_orders_count", ascending=False)
# Out:
#    seller_state  delivered_orders_count
# 21           SP                   82061
# 7            MG                    9026
# 14           PR                    8798
# 15           RJ                    4877
# 19           SC                    4180
# 18           RS                    2251
# 3            DF                     930
# 1            BA                     679
# 5            GO                     536
# 12           PE                     462
# 6            MA                     406
# 4            ES                     382
# 9            MT                     146
# 2            CE                      99
# 8            MS                      60
# 16           RN                      56
# 11           PB                      43
# 17           RO                      14
# 13           PI                      11
# 20           SE                      10
# 10           PA                       8
# 0            AM                       3

# %%
# Counting how many times the order_status was "processing" for each seller_state
delivered_orders_count = df[df['order_status'] == 'processing'].groupby('seller_state').size().reset_index(name='delivered_orders_count')
delivered_orders_count.sort_values(by="delivered_orders_count", ascending=False)
# Out:
#    seller_state  delivered_orders_count
# 10           SP                     228
# 7            RJ                      47
# 6            PR                      37
# 5            MG                      29
# 8            RS                      13
# 9            SC                      10
# 1            BA                       5
# 3            ES                       2
# 4            GO                       2
# 0            AC                       1
# 2            DF                       1

# %%
# Counting how many times the order_status was "created" for each seller_state
delivered_orders_count = df[df['order_status'] == 'created'].groupby('seller_state').size().reset_index(name='delivered_orders_count')
delivered_orders_count.sort_values(by="delivered_orders_count", ascending=False)
# Out:
#     seller_state  delivered_orders_count
# 0  Unknown State                       5

# %%
# Counting how many times the order_status was "approved" for each seller_state
delivered_orders_count = df[df['order_status'] == 'approved'].groupby('seller_state').size().reset_index(name='delivered_orders_count')
delivered_orders_count.sort_values(by="delivered_orders_count", ascending=False)
# Out:
#   seller_state  delivered_orders_count
# 0           MG                       2
# 1           SP                       1

# %%
# Calculating the delivery time in days and computing the average for each seller_id
df['delivery_time_days'] = (df['order_delivered_customer_date'] - df['order_approved_at']).dt.days
avg_delivery_time_per_seller = df.groupby('seller_id')['delivery_time_days'].mean().reset_index(name='avg_delivery_time_days')
avg_delivery_time_per_seller
# Out:
#   seller_id  avg_delivery_time_days
# 0        -1               11.190984

# %%
df["order_status"].unique()
# Out:
# array(['delivered', 'invoiced', 'shipped', 'processing', 'unavailable',
#        'canceled', 'created', 'approved'], dtype=object)

# %% [markdown]
# ## Date Manipulation

# %%
# Converting 'order_purchase_timestamp' to datetime
df['order_purchase_timestamp'] = pd.to_datetime(df['order_purchase_timestamp'])

# %%
# Extracting year and month from 'order_purchase_timestamp'
df['order_year'] = df['order_purchase_timestamp'].dt.year
df['order_month'] = df['order_purchase_timestamp'].dt.month
df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 3  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 4  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:00 2017-10-02 11:07:00
# 1    delivered      2017-10-02 10:56:00 2017-10-02 11:07:00
# 2    delivered      2017-10-02 10:56:00 2017-10-02 11:07:00
# 3    delivered      2018-07-24 20:41:00 2018-07-26 03:24:00
# 4    delivered      2018-08-08 08:38:00 2018-08-08 08:55:00
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:00
# ...

# %%
# Ensuring date columns are datetime
df['order_delivered_customer_date'] = pd.to_datetime(df['order_delivered_customer_date'])

# Calculating delivery days
df['delivery_days'] = (df['order_delivered_customer_date'] - df['order_purchase_timestamp']).dt.days
df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 3  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 4  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:00 2017-10-02 11:07:00
# 1    delivered      2017-10-02 10:56:00 2017-10-02 11:07:00
# 2    delivered      2017-10-02 10:56:00 2017-10-02 11:07:00
# 3    delivered      2018-07-24 20:41:00 2018-07-26 03:24:00
# 4    delivered      2018-08-08 08:38:00 2018-08-08 08:55:00
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:00
# ...

# %%
# Calculating 'delivery_time' in days
df['delivery_time'] = (df['order_delivered_customer_date'] - df['order_approved_at']).dt.days
df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 3  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 4  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:00 2017-10-02 11:07:00
# 1    delivered      2017-10-02 10:56:00 2017-10-02 11:07:00
# 2    delivered      2017-10-02 10:56:00 2017-10-02 11:07:00
# 3    delivered      2018-07-24 20:41:00 2018-07-26 03:24:00
# 4    delivered      2018-08-08 08:38:00 2018-08-08 08:55:00
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:00
# ...

# %%
# Checking if 'order_purchase_timestamp' is monotonically increasing
is_monotonic = df['order_purchase_timestamp'].is_monotonic_increasing
print(f"Is 'order_purchase_timestamp' monotonic? {is_monotonic}")
# Out:
# Is 'order_purchase_timestamp' monotonic? False

# %% [markdown]
# ## Feature Engineering

# %%
 # Creating bins for price into 3 categories low, medium, and high.
# Defining bins and labels
bins = [0, 50, 100, 200]
labels = ['Low', 'Medium', 'High']

# Creating 'price_category' based on bins
df['price_category'] = pd.cut(df['price'], bins=bins, labels=labels)
df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 3  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 4  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:00 2017-10-02 11:07:00
# 1    delivered      2017-10-02 10:56:00 2017-10-02 11:07:00
# 2    delivered      2017-10-02 10:56:00 2017-10-02 11:07:00
# 3    delivered      2018-07-24 20:41:00 2018-07-26 03:24:00
# 4    delivered      2018-08-08 08:38:00 2018-08-08 08:55:00
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:00
# ...

# %%
# Creating a Boolean mask for 'payment_installments' > 5
mask = df['payment_installments'] > 5
mask.head(40)
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7      True
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19     True
# 20     True
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32     True
# 33     True
# 34    False
# 35     True
# 36    False
# 37    False
# 38    False
# 39    False
# Name: payment_installments, dtype: bool

# %%
# Conditional Assignment
# Creating 'fast_delivery' flag based on 'delivery_time'
df['fast_delivery'] = df['delivery_time'].apply(lambda x: True if x < 5 else False)
df.head(22)
# Out:
#                             order_id                       customer_id  \
# 0   e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1   e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2   e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 3   53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 4   47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 5   949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 6   ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# 7   a4591c265e18cb1dcee52889e2d8acc3  503740e9ca751ccdda7ba28e9ab8f608
# 8   136cce7faa42fdb2cefd53fdc79a6098  ed0271e0b7da060a393796590e7b737a
# 9   6514b8ad8028c9f2cc2374ded245783f  9bdf08b4b3b52b5526ff42d37d47f222
# 10  76c6e866289321a7c93b82b54852dc33  f54a9f0e6b351c431402b8461ea51999
# 11  e69bfb5eb88e0ed6a785585b27e16dbf  31ad1d1b63eb9962463f764d4e6e0c9d
# ...

# %%
# Merging 'customer_city' and 'customer_state' into 'location'
df['location'] = df['customer_city'] + ', ' + df['customer_state']
df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 3  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 4  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:00 2017-10-02 11:07:00
# 1    delivered      2017-10-02 10:56:00 2017-10-02 11:07:00
# 2    delivered      2017-10-02 10:56:00 2017-10-02 11:07:00
# 3    delivered      2018-07-24 20:41:00 2018-07-26 03:24:00
# 4    delivered      2018-08-08 08:38:00 2018-08-08 08:55:00
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:00
# ...

# %%
# Spliting 'customer_city' into two separate columns
df[['city_part1', 'city_part2']] = df['customer_city'].str.split(' ', expand=True, n=1)
df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 3  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 4  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:00 2017-10-02 11:07:00
# 1    delivered      2017-10-02 10:56:00 2017-10-02 11:07:00
# 2    delivered      2017-10-02 10:56:00 2017-10-02 11:07:00
# 3    delivered      2018-07-24 20:41:00 2018-07-26 03:24:00
# 4    delivered      2018-08-08 08:38:00 2018-08-08 08:55:00
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:00
# ...

# %%
# Standarding specified numeric columns
df[['price_z', 'freight_value_z', 'payment_value_z']] = df[['price', 'freight_value', 'payment_value']].apply(lambda x: (x - x.mean()) / x.std())
df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 3  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 4  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:00 2017-10-02 11:07:00
# 1    delivered      2017-10-02 10:56:00 2017-10-02 11:07:00
# 2    delivered      2017-10-02 10:56:00 2017-10-02 11:07:00
# 3    delivered      2018-07-24 20:41:00 2018-07-26 03:24:00
# 4    delivered      2018-08-08 08:38:00 2018-08-08 08:55:00
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:00
# ...

# %% [markdown]
#  ## Encoding Categorical Variables

# %%
# Defing mapping for 'payment_type'
payment_mapping = {'credit_card': 1, 'voucher': 2, 'boleto': 3, 'debit_card': 4, 'not_defined': 5, 'UNKNOWN' : 6}

# Map 'payment_type' to numerical values
df['payment_type_encoded'] = df['payment_type'].map(payment_mapping)
df[['payment_type','payment_type_encoded']].head()
# Out:
#   payment_type  payment_type_encoded
# 0  credit_card                     1
# 1      voucher                     2
# 2      voucher                     2
# 3       boleto                     3
# 4  credit_card                     1

# %%
df['payment_type'].unique()
# Out:
# array(['credit_card', 'voucher', 'boleto', 'debit_card', 'not_defined',
#        'UNKNOWN'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
# Initializing LabelEncoder
le = LabelEncoder()

# Encode 'product_category_name_eng'
df['product_category_label'] = le.fit_transform(df['product_category_name_eng'])
df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 3  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 4  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:00 2017-10-02 11:07:00
# 1    delivered      2017-10-02 10:56:00 2017-10-02 11:07:00
# 2    delivered      2017-10-02 10:56:00 2017-10-02 11:07:00
# 3    delivered      2018-07-24 20:41:00 2018-07-26 03:24:00
# 4    delivered      2018-08-08 08:38:00 2018-08-08 08:55:00
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:00
# ...

# %% [markdown]
# ##  Data Transformation

# %% [markdown]
# ### pivot_table

# %%
# Creating a pivot table showing the total payment_value for each seller_state
pivot_basic = pd.pivot_table(df, values='payment_value', index='seller_state', aggfunc='sum').reset_index()
pivot_basic.sort_values(by='payment_value',ascending=False).head()
# Out:
#    seller_state  payment_value
# 22           SP    13369880.61
# 15           PR     1846372.26
# 8            MG     1564757.80
# 16           RJ     1098242.23
# 20           SC      886745.47

# %%
# Create a pivot table with multiple aggregations: sum of price and mean of freight_value by product_category_name_eng
pivot_multi_agg =  pd.pivot_table(df, values=['price', 'freight_value'],  
                                index='product_category_name_eng',
                                aggfunc={'price': 'sum', 'freight_value': 'mean'}).reset_index()
pivot_multi_agg.head()
# Out:
#     product_category_name_eng  freight_value     price
# 0  agro_industry_and_commerce      27.646111  83841.95
# 1            air_conditioning      22.677152  55962.38
# 2                         art      19.137078  24721.97
# 3       arts_and_craftmanship      15.422083   1814.01
# 4                       audio      15.736289  52450.37

# %%
# Creating a pivot table with margins to include the total sum
pivot_with_margins = pd.pivot_table(df, values='payment_value',   
                    index='seller_state', aggfunc='sum', margins=True, margins_name='Total').reset_index()
pivot_with_margins.head()
# Out:
#   seller_state  payment_value
# 0           AC         299.84
# 1           AM        1258.80
# 2           BA      367899.46
# 3           CE       25849.77
# 4           DF      137784.98

# %%
# Creating a pivot table with a custom aggregation function (median) for price
pivot_custom_agg = pd.pivot_table(df, values='price', 
                    index='product_category_name_eng', aggfunc=lambda x: x.median()).reset_index()
pivot_custom_agg.head()
# Out:
#     product_category_name_eng   price
# 0  agro_industry_and_commerce  299.95
# 1            air_conditioning  139.99
# 2                         art   97.50
# 3       arts_and_craftmanship   44.90
# 4                       audio   89.00

# %%
# Creating a pivot table showing the count of orders for each combination of product_category_name_eng and seller_id
pivot_count_orders = pd.pivot_table(df, values='order_id',
                    index=['product_category_name_eng', 'seller_id'], aggfunc='count').reset_index()
pivot_count_orders.head()
# Out:
#     product_category_name_eng seller_id  order_id
# 0  agro_industry_and_commerce        -1       252
# 1            air_conditioning        -1       302
# 2                         art        -1       219
# 3       arts_and_craftmanship        -1        24
# 4                       audio        -1       380

# %% [markdown]
# ### Cumulative Sum

# %%
# Calculating the cumulative sum of price for each seller_id
df['cumulative_price_seller'] = df.groupby('seller_id')['price'].cumsum()
df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 3  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 4  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:00 2017-10-02 11:07:00
# 1    delivered      2017-10-02 10:56:00 2017-10-02 11:07:00
# 2    delivered      2017-10-02 10:56:00 2017-10-02 11:07:00
# 3    delivered      2018-07-24 20:41:00 2018-07-26 03:24:00
# 4    delivered      2018-08-08 08:38:00 2018-08-08 08:55:00
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:00
# ...

# %%
# Converting order_purchase_timestamp to datetime and resample to month, then calculate cumulative sum of payment_value
df['order_purchase_timestamp'] = pd.to_datetime(df['order_purchase_timestamp'])
df.set_index('order_purchase_timestamp', inplace=True)
cumulative_sum_monthly = df['payment_value'].resample('M').cumsum().reset_index()

# %%
# Converting order_purchase_timestamp to datetime and resample to month, then calculate cumulative sum of payment_value
df['order_purchase_timestamp'] = pd.to_datetime(df['order_purchase_timestamp'])
df.set_index('order_purchase_timestamp', inplace=True)
cumulative_sum_monthly = df['payment_value'].resample('M').cumsum().reset_index()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\user\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'order_purchase_timestamp'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[109], line 2
# ...

# %%
# Calculating the cumulative sum of freight_value over time
df['cumulative_freight_value'] = df['freight_value'].cumsum()
df[['freight_value', 'cumulative_freight_value']].head()
# Out:
#                           freight_value  cumulative_freight_value
# order_purchase_timestamp
# 2017-10-02 10:56:00                8.72                      8.72
# 2017-10-02 10:56:00                8.72                     17.44
# 2017-10-02 10:56:00                8.72                     26.16
# 2018-07-24 20:41:00               22.76                     48.92
# 2018-08-08 08:38:00               19.22                     68.14

# %%
# Calculating cumulative sum of price with a reset for each new product_id
df['cumulative_price_per_product'] = df.groupby('product_id')['price'].cumsum()
df[['product_id','price', 'cumulative_price_per_product']].head()
# Out:
#                          product_id   price  cumulative_price_per_product
# order_purchase_timestamp
# 2017-10-02 10:56:00              -1   29.99                         29.99
# 2017-10-02 10:56:00              -1   29.99                         59.98
# 2017-10-02 10:56:00              -1   29.99                         89.97
# 2018-07-24 20:41:00              -1  118.70                        208.67
# 2018-08-08 08:38:00              -1  159.90                        368.57

# %%
# Calculating cumulative sum of prices, excluding rows where price is less than 50
df_filtered = df[df['price'] >= 50]
df_filtered['cumulative_price_filtered'] = df_filtered['price'].cumsum()
df_filtered[['price']].head()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_14188\1359465851.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['cumulative_price_filtered'] = df_filtered['price'].cumsum()
#                            price
# order_purchase_timestamp
# 2018-07-24 20:41:00       118.70
# 2018-08-08 08:38:00       159.90
# 2017-07-09 21:57:00       147.90
# 2017-05-16 13:10:00        59.99
# 2017-07-29 11:55:00       149.99

# %% [markdown]
# ### Rolling Window Calculations Techniques

# %%
# Calculating the rolling mean of price with a 2-day window
df['rolling_mean_price'] = df['price'].rolling(window=2).mean()
df[['price', 'rolling_mean_price']].head()
# Out:
#                            price  rolling_mean_price
# order_purchase_timestamp
# 2017-10-02 10:56:00        29.99                 NaN
# 2017-10-02 10:56:00        29.99              29.990
# 2017-10-02 10:56:00        29.99              29.990
# 2018-07-24 20:41:00       118.70              74.345
# 2018-08-08 08:38:00       159.90             139.300

# %%
# Calculating the rolling sum of payment_value with a 30-day window
df['rolling_sum_payment'] = df['payment_value'].rolling(window=30, min_periods=1).sum()
df[["rolling_sum_payment", 'payment_value']].head()
# Out:
#                           rolling_sum_payment  payment_value
# order_purchase_timestamp
# 2017-10-02 10:56:00                     18.12          18.12
# 2017-10-02 10:56:00                     20.12           2.00
# 2017-10-02 10:56:00                     38.71          18.59
# 2018-07-24 20:41:00                    180.17         141.46
# 2018-08-08 08:38:00                    359.29         179.12

# %%
# Calculating the rolling standard deviation of freight_value with a 14-day window
df['rolling_std_freight'] = df['freight_value'].rolling(window=14).std()
df[['rolling_std_freight','freight_value']].head(30)
# Out:
#                           rolling_std_freight  freight_value
# order_purchase_timestamp
# 2017-10-02 10:56:00                       NaN           8.72
# 2017-10-02 10:56:00                       NaN           8.72
# 2017-10-02 10:56:00                       NaN           8.72
# 2018-07-24 20:41:00                       NaN          22.76
# 2018-08-08 08:38:00                       NaN          19.22
# 2017-11-18 19:28:00                       NaN          27.20
# 2018-02-13 21:18:00                       NaN           8.72
# 2017-07-09 21:57:00                       NaN          27.36
# 2017-04-11 12:22:00                       NaN          16.05
# 2017-05-16 13:10:00                       NaN          15.17
# 2017-01-23 18:29:00                       NaN          16.05
# 2017-07-29 11:55:00                       NaN          19.77
# 2017-07-29 11:55:00                       NaN          19.77
# 2017-05-16 19:41:00                  7.436914          30.53
# ...

# %%
# Calculating the rolling maximum of payment_value over a 16-day window
df['rolling_max_payment'] = df['payment_value'].rolling(window=16).max()
df[['rolling_max_payment', 'payment_value']].head()
# Out:
#                           rolling_max_payment  payment_value
# order_purchase_timestamp
# 2017-10-02 10:56:00                       NaN          18.12
# 2017-10-02 10:56:00                       NaN           2.00
# 2017-10-02 10:56:00                       NaN          18.59
# 2018-07-24 20:41:00                       NaN         141.46
# 2018-08-08 08:38:00                       NaN         179.12

# %%
# Calculate the rolling minimum of price over a 90-day window
df['rolling_min_price'] = df['price'].rolling(window=90).min()
df[["rolling_min_price", "price"]].head()
# Out:
#                           rolling_min_price   price
# order_purchase_timestamp
# 2017-10-02 10:56:00                     NaN   29.99
# 2017-10-02 10:56:00                     NaN   29.99
# 2017-10-02 10:56:00                     NaN   29.99
# 2018-07-24 20:41:00                     NaN  118.70
# 2018-08-08 08:38:00                     NaN  159.90

# %% [markdown]
# ### Shift Values Techniques

# %%
# Shifting price values by 1 row to show the previous order's price
df['previous_price'] = df['price'].shift(1)
df[["previous_price", "price"]].head()
# Out:
#                           previous_price   price
# order_purchase_timestamp
# 2017-10-02 10:56:00                  NaN   29.99
# 2017-10-02 10:56:00                29.99   29.99
# 2017-10-02 10:56:00                29.99   29.99
# 2018-07-24 20:41:00                29.99  118.70
# 2018-08-08 08:38:00               118.70  159.90

# %%
# Shifting payment_value by 3 rows to compare with the payment value from 3 rows ago
df['payment_value_shift_3'] = df['payment_value'].shift(3)
df[['payment_value_shift_3', 'payment_value']].head()
# Out:
#                           payment_value_shift_3  payment_value
# order_purchase_timestamp
# 2017-10-02 10:56:00                         NaN          18.12
# 2017-10-02 10:56:00                         NaN           2.00
# 2017-10-02 10:56:00                         NaN          18.59
# 2018-07-24 20:41:00                       18.12         141.46
# 2018-08-08 08:38:00                        2.00         179.12

# %%
# Creating lagging features for order_purchase_timestamp to compare with the date from the previous row
df['previous_order_date'] = df['order_delivered_customer_date'].shift(1)
df[['order_delivered_customer_date', 'previous_order_date']].head()
# Out:
#                          order_delivered_customer_date previous_order_date
# order_purchase_timestamp
# 2017-10-02 10:56:00                2017-10-10 21:25:00                 NaT
# 2017-10-02 10:56:00                2017-10-10 21:25:00 2017-10-10 21:25:00
# 2017-10-02 10:56:00                2017-10-10 21:25:00 2017-10-10 21:25:00
# 2018-07-24 20:41:00                2018-08-07 15:27:00 2017-10-10 21:25:00
# 2018-08-08 08:38:00                2018-08-17 18:06:00 2018-08-07 15:27:00

# %%
# Calculating the change in price compared to the previous row
df['price_change'] = df['price'].diff()
df[["price_change", "price"]].head()
# Out:
#                           price_change   price
# order_purchase_timestamp
# 2017-10-02 10:56:00                NaN   29.99
# 2017-10-02 10:56:00               0.00   29.99
# 2017-10-02 10:56:00               0.00   29.99
# 2018-07-24 20:41:00              88.71  118.70
# 2018-08-08 08:38:00              41.20  159.90

# %%
# Creating a lagging feature for freight_value by 2 rows
df['freight_value_lag_2'] = df['freight_value'].shift(2)
df[["freight_value", "freight_value_lag_2"]].head()
# Out:
#                           freight_value  freight_value_lag_2
# order_purchase_timestamp
# 2017-10-02 10:56:00                8.72                  NaN
# 2017-10-02 10:56:00                8.72                  NaN
# 2017-10-02 10:56:00                8.72                 8.72
# 2018-07-24 20:41:00               22.76                 8.72
# 2018-08-08 08:38:00               19.22                 8.72

# %% [markdown]
# ##  Outlier Detection

# %%
# Calculating Q1 and Q3 for 'price'
Q1 = df['price'].quantile(0.25)
Q3 = df['price'].quantile(0.75)
IQR = Q3 - Q1

# Define outlier boundaries
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify outliers
outliers = df[(df['price'] < lower_bound) | (df['price'] > upper_bound)]

outliers.head()
# Out:
#                                                   order_id  \
# order_purchase_timestamp
# 2018-01-02 19:00:00       403b97836b0c04a622354cf531062e5f
# 2017-08-10 11:58:00       f70a0aff17df5a6cdd9a7196128bd354
# 2018-06-01 12:23:00       434d158e96bdd6972ad6e6d73ddcfd22
# 2017-11-24 21:27:00       6ea2f835b4556291ffdc53fa0b3b95e8
# 2017-12-15 00:06:00       641fb0752bf5b5940c376b3a8bb9dc52
#
#                                                customer_id order_status  \
# order_purchase_timestamp
# 2018-01-02 19:00:00       738b086814c6fcc74b8cc583f8516ee3    delivered
# 2017-08-10 11:58:00       456dc10730fbdba34615447ea195d643    delivered
# 2018-06-01 12:23:00       2a1dfb647f32f4390e7b857c67458536    delivered
# 2017-11-24 21:27:00       c7340080e394356141681bd4c9b8fe31    delivered
# 2017-12-15 00:06:00       f5afca14dfa9dc64251cf2b45c54c363    delivered
#
#                            order_approved_at order_delivered_carrier_date  \
# order_purchase_timestamp
# ...

# %%
 # Calculate Z-Score
# Calculating z-score for 'payment_value'
df['z_score_payment'] = (df['payment_value'] - df['payment_value'].mean()) / df['payment_value'].std()

# Identify extreme values (e.g., |z| > 3)
extreme_payments = df[df['z_score_payment'].abs() > 3]
extreme_payments.head()
# Out:
#                                                   order_id  \
# order_purchase_timestamp
# 2018-01-02 19:00:00       403b97836b0c04a622354cf531062e5f
# 2017-09-13 15:07:00       f04bfdbef5359607d39e66fccc9cc0de
# 2017-09-13 15:07:00       f04bfdbef5359607d39e66fccc9cc0de
# 2017-09-13 15:07:00       f04bfdbef5359607d39e66fccc9cc0de
# 2017-09-13 15:07:00       f04bfdbef5359607d39e66fccc9cc0de
#
#                                                customer_id order_status  \
# order_purchase_timestamp
# 2018-01-02 19:00:00       738b086814c6fcc74b8cc583f8516ee3    delivered
# 2017-09-13 15:07:00       ddbd5d378c4a0981ba1ef29fb8e40b8f    delivered
# 2017-09-13 15:07:00       ddbd5d378c4a0981ba1ef29fb8e40b8f    delivered
# 2017-09-13 15:07:00       ddbd5d378c4a0981ba1ef29fb8e40b8f    delivered
# 2017-09-13 15:07:00       ddbd5d378c4a0981ba1ef29fb8e40b8f    delivered
#
#                            order_approved_at order_delivered_carrier_date  \
# order_purchase_timestamp
# ...

# %% [markdown]
# ## String Operations and Matching

# %%
# Filtering rows where 'product_category_name_eng' contains 'electronics' (case-insensitive)
df_electronics = df[df['product_category_name_eng'].str.contains('electronics', case=False, na=False)]
df_electronics['product_category_name_eng'].head()
# Out:
# order_purchase_timestamp
# 2018-02-03 20:37:00    electronics
# 2018-02-21 18:15:00    electronics
# 2018-07-15 12:37:00    electronics
# 2017-11-06 18:20:00    electronics
# 2017-11-06 18:20:00    electronics
# Name: product_category_name_eng, dtype: object

# %%
# Finding rows where 'customer_city' contains 'Rio' (case-insensitive)
df_rio = df[df['customer_city'].str.contains('Rio', case=False, na=False)]
df_rio['customer_city'].head()
# Out:
# order_purchase_timestamp
# 2017-05-16 19:41:00    rio de janeiro
# 2017-05-16 19:41:00    rio de janeiro
# 2018-01-02 19:00:00    rio de janeiro
# 2018-02-20 23:46:00    rio de janeiro
# 2017-05-18 13:55:00    rio de janeiro
# Name: customer_city, dtype: object

# %% [markdown]
# ## Correlation Analysis

# %%
# Calculating Pearson correlation between 'price' and 'freight_value'
correlation = df[['price', 'freight_value']].corr()
correlation
# Out:
#                   price  freight_value
# price          1.000000       0.416054
# freight_value  0.416054       1.000000

# %%
# Calculating correlation matrix
corr_matrix = df.corr().abs()

# Select upper triangle of correlation matrix
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(bool))

# Find columns with correlation > 0.8
highly_corr = [column for column in upper.columns if any(upper[column] > 0.8)]
print(f"Highly correlated columns: {highly_corr}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[156], line 2
#       1 # Calculating correlation matrix
# ----> 2 corr_matrix = df.corr().abs()
#       4 # Select upper triangle of correlation matrix
#       5 upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(bool))
#
# File c:\Users\user\anaconda3\Lib\site-packages\pandas\core\frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File c:\Users\user\anaconda3\Lib\site-packages\pandas\core\frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1991 if dtype is not None:
#    1992     dtype = np.dtype(dtype)
# ...

# %% [markdown]
# ##  Quantile-Based Filtering

# %%
# Calculating the 90th percentile of 'price'
price_90th = df['price'].quantile(0.9)

# Filter rows with 'price' >= 90th percentile
top_10_percent = df[df['price'] >= price_90th]
top_10_percent.head()
# Out:
#                                                   order_id  \
# order_purchase_timestamp
# 2018-01-02 19:00:00       403b97836b0c04a622354cf531062e5f
# 2017-08-10 11:58:00       f70a0aff17df5a6cdd9a7196128bd354
# 2018-06-01 12:23:00       434d158e96bdd6972ad6e6d73ddcfd22
# 2017-11-24 21:27:00       6ea2f835b4556291ffdc53fa0b3b95e8
# 2017-12-15 00:06:00       641fb0752bf5b5940c376b3a8bb9dc52
#
#                                                customer_id order_status  \
# order_purchase_timestamp
# 2018-01-02 19:00:00       738b086814c6fcc74b8cc583f8516ee3    delivered
# 2017-08-10 11:58:00       456dc10730fbdba34615447ea195d643    delivered
# 2018-06-01 12:23:00       2a1dfb647f32f4390e7b857c67458536    delivered
# 2017-11-24 21:27:00       c7340080e394356141681bd4c9b8fe31    delivered
# 2017-12-15 00:06:00       f5afca14dfa9dc64251cf2b45c54c363    delivered
#
#                            order_approved_at order_delivered_carrier_date  \
# order_purchase_timestamp
# ...

# %% [markdown]
# ## Data Resampling

# %%
# Ensure 'order_purchase_timestamp' is datetime and set as index
df['order_purchase_timestamp'] = pd.to_datetime(df['order_purchase_timestamp'])
df.set_index('order_purchase_timestamp', inplace=True)

# Resample by month and sum 'payment_value'
df_monthly = df.resample('M')['payment_value'].sum().reset_index()

# Reset index if necessary
df.reset_index(inplace=True)
df_monthly.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\user\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'order_purchase_timestamp'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[158], line 2
# ...

# %% [markdown]
# ## Count Distinct Values

# %%
# Count distinct 'customer_id'
distinct_customers = df['customer_id'].nunique()
print(f"Number of distinct customers: {distinct_customers}")
# Out:
# Number of distinct customers: 99441

# %% [markdown]
# ## Data sorting

# %%
# Sorting 'order_purchase_timestamp' ascending and 'price' descending
df_sorted = df.sort_values(by=['order_purchase_timestamp', 'price'], ascending=[True, False])
df_sorted['price'].head()
# Out:
# order_purchase_timestamp
# 2016-09-04 21:15:00    39.99
# 2016-09-04 21:15:00    32.90
# 2016-09-05 00:15:00    59.50
# 2016-09-13 15:24:00    74.90
# 2016-09-15 12:16:00    44.99
# Name: price, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 118434 entries, 2017-10-02 10:56:00 to 2018-03-08 20:57:00
# Data columns (total 58 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       118434 non-null  object
#  1   customer_id                    118434 non-null  object
#  2   order_status                   118434 non-null  object
#  3   order_approved_at              118434 non-null  datetime64[ns]
#  4   order_delivered_carrier_date   118434 non-null  datetime64[ns]
#  5   order_delivered_customer_date  118434 non-null  datetime64[ns]
#  6   order_estimated_delivery_date  118434 non-null  datetime64[ns]
#  7   order_item_id                  118434 non-null  int64
#  8   product_id                     118434 non-null  object
#  9   seller_id                      118434 non-null  object
#  10  shipping_limit_date            118434 non-null  datetime64[ns]
# ...

# %%
# Saving the manipulated data 
df.to_csv(r"C:\Users\user\Desktop\#\DA\practice\python\E - commerce\cleaned_data sets\EDA.csv")

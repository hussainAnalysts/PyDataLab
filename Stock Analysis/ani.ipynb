# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation

# %%
int = pd.read_csv(r"C:\Users\user\Desktop\#\DA\practice\python\Stock Analysis\intel.csv")
nvd = pd.read_csv(r"C:\Users\user\Desktop\#\DA\practice\python\Stock Analysis\nvidia.csv")
amd = pd.read_csv(r"C:\Users\user\Desktop\#\DA\practice\python\Stock Analysis\amd.csv")

# %%
int.head()
# Out:
#          Date Close/Last    Volume     Open     High      Low
# 0  11/29/2024    $24.05   36616750  $23.72   $24.28   $23.60
# 1  11/27/2024    $23.65   53992320  $23.83   $23.93   $23.06
# 2  11/26/2024    $24.05   69613560  $24.95   $24.99   $23.81
# 3  11/25/2024    $24.87   91128390  $25.04   $25.57   $24.76
# 4  11/22/2024    $24.50   36784720  $24.35   $24.68   $24.14

# %%
amd.head()
# Out:
#          Date Close/Last    Volume     Open       High      Low
# 0  11/29/2024   $137.175  16085710  $136.24  $138.5876  $135.78
# 1  11/27/2024    $136.24  30175290  $137.20    $137.94  $132.96
# 2  11/26/2024    $137.72  32092380  $142.55    $142.80  $136.62
# 3  11/25/2024    $141.13  30923110  $140.49    $142.35  $139.05
# 4  11/22/2024    $138.35  21784730  $137.35    $139.13  $137.04

# %%
nvd.head()
# Out:
#          Date Close/Last     Volume     Open     High      Low
# 0  11/29/2024    $138.25  141863200  $136.78  $139.35  $136.05
# 1  11/27/2024    $135.34  226370900  $135.01  $137.22  $131.80
# 2  11/26/2024    $136.92  190287700  $137.70  $139.30  $135.67
# 3  11/25/2024    $136.02  344941900  $141.99  $142.05  $135.82
# 4  11/22/2024    $141.95  236406200  $145.93  $147.16  $141.10

# %%
# Strip out any dollar signs and extra spaces, then convert to float
int['Close/Last'] = int['Close/Last'].replace({'\$': '', ' ': ''}, regex=True).astype(float)
amd['Close/Last'] = amd['Close/Last'].replace({'\$': '', ' ': ''}, regex=True).astype(float)
nvd['Close/Last'] = nvd['Close/Last'].replace({'\$': '', ' ': ''}, regex=True).astype(float)

# Do the same for other columns that may have dollar signs or spaces
int['Open'] = int['Open'].replace({'\$': '', ' ': ''}, regex=True).astype(float)
int['High'] = int['High'].replace({'\$': '', ' ': ''}, regex=True).astype(float)
int['Low'] = int['Low'].replace({'\$': '', ' ': ''}, regex=True).astype(float)

amd['Open'] = amd['Open'].replace({'\$': '', ' ': ''}, regex=True).astype(float)
amd['High'] = amd['High'].replace({'\$': '', ' ': ''}, regex=True).astype(float)
amd['Low'] = amd['Low'].replace({'\$': '', ' ': ''}, regex=True).astype(float)

nvd['Open'] = nvd['Open'].replace({'\$': '', ' ': ''}, regex=True).astype(float)
nvd['High'] = nvd['High'].replace({'\$': '', ' ': ''}, regex=True).astype(float)
nvd['Low'] = nvd['Low'].replace({'\$': '', ' ': ''}, regex=True).astype(float)

# Check the data types again
print(int.dtypes)
print(amd.dtypes)
print(nvd.dtypes)
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\$'
# <>:3: SyntaxWarning: invalid escape sequence '\$'
# <>:4: SyntaxWarning: invalid escape sequence '\$'
# <>:7: SyntaxWarning: invalid escape sequence '\$'
# <>:8: SyntaxWarning: invalid escape sequence '\$'
# <>:9: SyntaxWarning: invalid escape sequence '\$'
# <>:11: SyntaxWarning: invalid escape sequence '\$'
# <>:12: SyntaxWarning: invalid escape sequence '\$'
# <>:13: SyntaxWarning: invalid escape sequence '\$'
# <>:15: SyntaxWarning: invalid escape sequence '\$'
# <>:16: SyntaxWarning: invalid escape sequence '\$'
# <>:17: SyntaxWarning: invalid escape sequence '\$'
# <>:2: SyntaxWarning: invalid escape sequence '\$'
# <>:3: SyntaxWarning: invalid escape sequence '\$'
# <>:4: SyntaxWarning: invalid escape sequence '\$'
# <>:7: SyntaxWarning: invalid escape sequence '\$'
# <>:8: SyntaxWarning: invalid escape sequence '\$'
# <>:9: SyntaxWarning: invalid escape sequence '\$'
# <>:11: SyntaxWarning: invalid escape sequence '\$'
# ...

# %%
# Ensure 'Date' column is in datetime format
int['Date'] = pd.to_datetime(int['Date'])
amd['Date'] = pd.to_datetime(amd['Date'])
nvd['Date'] = pd.to_datetime(nvd['Date'])

# %%
# Check the data types again
print(int.dtypes)
print(amd.dtypes)
print(nvd.dtypes)
# Out:
# Date          datetime64[ns]
# Close/Last           float64
# Volume                 int64
# Open                 float64
# High                 float64
# Low                  float64
# dtype: object
# Date          datetime64[ns]
# Close/Last           float64
# Volume                 int64
# Open                 float64
# High                 float64
# Low                  float64
# dtype: object
# Date          datetime64[ns]
# Close/Last           float64
# Volume                 int64
# Open                 float64
# High                 float64
# Low                  float64
# dtype: object

# %%
amd = amd_df 
nvd = nvidia_df 
int = intel_df

# %%
amd
# Out:
#             Date Close/Last    Volume     Open       High      Low
# 0     11/29/2024   $137.175  16085710  $136.24  $138.5876  $135.78
# 1     11/27/2024    $136.24  30175290  $137.20    $137.94  $132.96
# 2     11/26/2024    $137.72  32092380  $142.55    $142.80  $136.62
# 3     11/25/2024    $141.13  30923110  $140.49    $142.35  $139.05
# 4     11/22/2024    $138.35  21784730  $137.35    $139.13  $137.04
# ...          ...        ...       ...      ...        ...      ...
# 2512  12/05/2014      $2.66   9445695    $2.69      $2.70    $2.66
# 2513  12/04/2014      $2.69  15538960    $2.75      $2.75    $2.66
# 2514  12/03/2014      $2.74  18256490    $2.71      $2.82    $2.69
# 2515  12/02/2014      $2.68  12437740    $2.69      $2.71    $2.61
# 2516  12/01/2014      $2.67  16013070    $2.77      $2.79    $2.64
#
# [2517 rows x 6 columns]

# %%
# Ploting the trend
plt.figure(figsize=(10, 6))
plt.plot(int['Date'], int['Close/Last'], label='Close Price', color='blue')
plt.title('Intel Stock Price Trend', fontsize=10)
plt.xlabel('Date', fontsize=8)
plt.ylabel('Close Price (USD)', fontsize=8)
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)
plt.legend(fontsize=8)
plt.savefig('intel_stock_trend.png', dpi=700, bbox_inches='tight')

plt.show()

# %%
# Plotting the trend
plt.figure(figsize=(10, 6))
plt.plot(nvd['Date'], nvd['Close/Last'], label='Close Price', color='blue')
plt.title('Nvidia Stock Price Trend', fontsize=10)
plt.xlabel('Date', fontsize=8)
plt.ylabel('Close Price (USD)', fontsize=8)
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)
plt.legend(fontsize=8)

# Save the figure as an image (e.g., PNG format)
plt.savefig('nvidia_stock_trend.png', dpi=700, bbox_inches='tight')

# Display the plot
plt.show()
